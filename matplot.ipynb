# %% [markdown]
# # Matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(1,11)
y = np.arange(1,11)
plt.title("Graph")
plt.xlabel("Nums 1")
plt.ylabel("Nums 2")
plt.plot(x,y)
